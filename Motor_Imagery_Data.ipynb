# %%
pip install moabb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from moabb.datasets import BNCI2014001, Cho2017, PhysionetMI

# %%
BNCI = BNCI2014001()
BNCI.get_data()
# Out:
# ...
# SHA256 hash of downloaded file: 054f02e70cf9c4ada1517e9b9864f45407939c1062c6793516585c6f511d0325
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# ...
# SHA256 hash of downloaded file: 53d415f39c3d7b0c88b894d7b08d99bcdfe855ede63831d3691af1a45607fb62
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# ...
# SHA256 hash of downloaded file: 5ddd5cb520b1692c3ba1363f48d98f58f0e46f3699ee50d749947950fc39db27
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# ...
# SHA256 hash of downloaded file: d63c454005d3a9b41d8440629482e855afc823339bdd0b5721842a7ee9cc7b12
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# ...

# %%
Cho = Cho2017()
Cho.get_data()
# Out:
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# ...

# %%
Phy = PhysionetMI()

Phy.get_data()
# Out:
# {1: {'session_0': {'run_4': <RawEDF | S001R04.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>,
#    'run_8': <RawEDF | S001R08.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>,
#    'run_12': <RawEDF | S001R12.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>,
#    'run_6': <RawEDF | S001R06.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>,
#    'run_10': <RawEDF | S001R10.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>,
#    'run_14': <RawEDF | S001R14.edf, 64 x 20000 (125.0 s), ~9.9 MB, data loaded>}},
#  2: {'session_0': {'run_4': <RawEDF | S002R04.edf, 64 x 19680 (123.0 s), ~9.7 MB, data loaded>,
#    'run_8': <RawEDF | S002R08.edf, 64 x 19680 (123.0 s), ~9.7 MB, data loaded>,
#    'run_12': <RawEDF | S002R12.edf, 64 x 19680 (123.0 s), ~9.7 MB, data loaded>,
#    'run_6': <RawEDF | S002R06.edf, 64 x 19680 (123.0 s), ~9.7 MB, data loaded>,
#    'run_10': <RawEDF | S002R10.edf, 64 x 19680 (123.0 s), ~9.7 MB, data loaded>,
# ...
